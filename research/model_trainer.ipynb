# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np 
import pandas as pd 
from keras.models import Sequential
from keras.layers import Dense, Flatten, BatchNormalization, Dropout
from keras.losses import SparseCategoricalCrossentropy
import matplotlib.pyplot as plt

# %%
print("Demo")
# Out:
# Demo

# %%
train_df= pd.read_csv(r'C:\Users\Arvind Vasa\AI-ML\myprojects\mnist_end_to_end\artifacts\train_data.csv')
test_df= pd.read_csv(r'C:\Users\Arvind Vasa\AI-ML\myprojects\mnist_end_to_end\artifacts\test_data.csv')

# %%
x_train= train_df.drop('label', axis=1).values.reshape(train_df.shape[0], 28, 28)
x_test= test_df.drop('label', axis=1).values.reshape(test_df.shape[0], 28, 28)

# %%
y_train= train_df['label']
y_test= test_df['label']

# %%
plt.figure(figsize= (15, 15))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(x_train[i])
    plt.xlabel(train_df['label'][i])
plt.show()

# %%
# (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# x_train[0].shape
# Out:
# (28, 28)

# %%
model = Sequential([
    Flatten(input_shape=(28, 28, 1)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')  # Assuming this is the output layer for a classification task
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 784)               0
#
#  dense_9 (Dense)             (None, 128)               100480
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dense_11 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109386 (427.29 KB)
# Trainable params: 109386 (427.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer= 'adam', loss= keras.losses.sparse_categorical_crossentropy, metrics= ['accuracy'])

# %%
history= model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs= 20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 9s 4ms/step - loss: 1.7513 - accuracy: 0.8655 - val_loss: 0.4671 - val_accuracy: 0.9114
# Epoch 2/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3067 - accuracy: 0.9274 - val_loss: 0.2817 - val_accuracy: 0.9306
# Epoch 3/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2068 - accuracy: 0.9441 - val_loss: 0.2257 - val_accuracy: 0.9450
# Epoch 4/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1698 - accuracy: 0.9525 - val_loss: 0.1939 - val_accuracy: 0.9497
# Epoch 5/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1462 - accuracy: 0.9589 - val_loss: 0.2149 - val_accuracy: 0.9496
# Epoch 6/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1276 - accuracy: 0.9645 - val_loss: 0.1456 - val_accuracy: 0.9598
# Epoch 7/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1139 - accuracy: 0.9688 - val_loss: 0.1540 - val_accuracy: 0.9590
# Epoch 8/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1062 - accuracy: 0.9702 - val_loss: 0.1651 - val_accuracy: 0.9573
# Epoch 9/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0962 - accuracy: 0.9742 - val_loss: 0.1672 - val_accuracy: 0.9593
# Epoch 10/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0878 - accuracy: 0.9762 - val_loss: 0.1258 - val_accuracy: 0.9687
# Epoch 11/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0871 - accuracy: 0.9761 - val_loss: 0.1333 - val_accuracy: 0.9691
# Epoch 12/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0780 - accuracy: 0.9788 - val_loss: 0.1486 - val_accuracy: 0.9662
# Epoch 13/20
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0767 - accuracy: 0.9793 - val_loss: 0.1929 - val_accuracy: 0.9625
# Epoch 14/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0695 - accuracy: 0.9804 - val_loss: 0.1721 - val_accuracy: 0.9656
# Epoch 15/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0713 - accuracy: 0.9815 - val_loss: 0.1591 - val_accuracy: 0.9691
# Epoch 16/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0676 - accuracy: 0.9815 - val_loss: 0.1697 - val_accuracy: 0.9669
# Epoch 17/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0617 - accuracy: 0.9839 - val_loss: 0.1802 - val_accuracy: 0.9654
# Epoch 18/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0665 - accuracy: 0.9831 - val_loss: 0.1737 - val_accuracy: 0.9656
# Epoch 19/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0645 - accuracy: 0.9837 - val_loss: 0.1978 - val_accuracy: 0.9637
# Epoch 20/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0542 - accuracy: 0.9855 - val_loss: 0.1906 - val_accuracy: 0.9683

# %%
x_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x_train
#
# NameError: name 'x_train' is not defined
